# %%
import json
import pandas as pd
import PIL.Image as Image
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm as CM

# %%
def read_image_and_gt(fname):
    img_path = fname
    gt_path = fname.replace('.jpg', '.csv').replace('img', 'den')

    img = Image.open(img_path)
    if img.mode == 'L':
        img = img.convert('RGB')

    den = pd.read_csv(gt_path, sep=',', header=None).values

    den = den.astype(np.float32, copy=False)
    return img, den

# %%
img_path = 'D:\\OneDrive\\OneDrive - UvA\\ThesisData\Datasets\\WE_C3_PP\\train\\img\\\
104242-GKWEntran04-S20100821070000000E20100821190000000_14_clip1_2.jpg'
img_path2 = 'D:\\OneDrive\\OneDrive - UvA\\ThesisData\Datasets\\WE_C3_PP\\train\\img\\\
100162_A02-02-S20100626080000000E20100626233000000.split.106_2.jpg'
img_path3 = 'D:\\OneDrive\\OneDrive - UvA\\ThesisData\Datasets\\WE_C3_PP\\train\\img\\\
100730_B03CamboNW-04-S20100626083000000E20100626233059000_new.split.326_2.jpg'

# %%
img, den = read_image_and_gt(img_path3)

# %%
plt.rcParams['figure.dpi'] = 200
fig, axarr = plt.subplots(1, 2) 
fig.tight_layout()

axarr[0].imshow(img)
axarr[0].set_title('Input image')
axarr[1].imshow(den,cmap=CM.jet)
axarr[1].set_title(f'gt den')
# Out:
# Text(0.5, 1.0, 'gt den')
